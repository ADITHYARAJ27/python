# %% [markdown]
# <a href="https://colab.research.google.com/github/ADITHYARAJ27/python/blob/main/python_basics.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
mset={1,2,3}
print(mset)
# Out:
# {1, 2, 3}

# %%
mset.add(4)
print(mset)
# Out:
# {1, 2, 3, 4}

# %%
mset.update([4,5,6,7])
print(mset)
# Out:
# {1, 2, 3, 4, 5, 6, 7}

# %%
mset.remove(2)
print(mset)
# Out:
# {1, 3, 4, 5, 6, 7}

# %%
#an element which is not in this will show an error

mset.remove(9)
print(mset)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipython-input-2694734355.py in <cell line: 0>()
#       1 #an element which is not in this will show an error
#       2
# ----> 3 mset.remove(9)
#       4 print(mset)
#
# KeyError: 9

# %%
#where in discard it will not show any error message

mset.discard(9)
print(mset)

# %%
mset.discard(6)
print(mset)

# %%
#pops a randon number from the list

poppeditem=mset.pop()
print(poppeditem)
print(mset)

# %%
#clears all the elemetns in set

mset.clear()
print(mset)

# %%
#union

set1={1,2,3,4}
set2={4,5,6,7}

unionset= set1 | set2
print(unionset)

# %%
#intersection

inte= set1 & set2
print(inte)

# %%
diff = set1 - set2
print(diff)

# %%
#symmetric difference

sd= set1 ^ set2
print(sd)

# %%
#subset and superset

#set1 = 1-100
#set2 = 20-60

#set1 is a superset of set2
#set2 is a subset of set1

# %%
set1 = {1,2,3,4,5}
set2 = {2,3}

print(set1.issubset(set2))
print(set1.issuperset(set2))
print(set2.issubset(set1))

# %%
#disjoint set -  sets which doesnt contain any common elements.

set1={1,2,3,4}
set2={5,6,7}

print(set1.isdisjoint(set2))
# Out:
# True

# %%
set1={1,2,3,4,5}
set2={5,6,7}

print(set1.isdisjoint(set2))
# Out:
# False

# %%
rows = 5

for i in range(1, rows + 1):
    # Print '*' i times
    print('*' * i)
# Out:
# *
# **
# ***
# ****
# *****

# %% [markdown]
# Functions

# %%
def function_name(paramter):
  ''' define the function'''
  return value

# %%
#basic function without parameter

def greet():
  print("hello,welcome to blearn")

greet()
# Out:
# hello,welcome to blearn

# %%
#basic funciton with parameters

def greet(name):
  print("hello",name,"welcome to blearn")

greet("adarsh")  #positional arguments
greet(name = "amar")  #keyword arguments
# Out:
# hello adarsh welcome to blearn
# hello amar welcome to blearn

# %%
#function with two parameters

def respond(name,age):
  print("hello",name,"and he is",age,"years old")

respond("abhi",26) #posititonal parameter
respond(26,"abhi")
# Out:
# hello abhi and he is 26 years old
# hello 26 and he is abhi years old

# %%
#keyword parameter

def respond(name,age):
  print("hello",name,"and he is",age,"years old")

respond(name="abhi",age=22)
# Out:
# hello abhi and he is 22 years old

# %%
#default parameter

def respond(name="amar",age=26):
  print("hello",name,"and he is",age,"years old")

respond("abhi",30)

respond()
# Out:
# hello abhi and he is 30 years old
# hello amar and he is 26 years old

# %%
#fucntion with variable arguments

def add(*args):
  return sum(args)

result=add(1,2,3,4,5)
print(result)
# Out:
# 15

# %%
num=6
a=0
x=num
while num>0:
  w = a*x
  x+-1
print(w)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipython-input-3428173993.py in <cell line: 0>()
#       2 a=0
#       3 x=num
# ----> 4 while num>0:
#       5   w = a*x
#       6   x+-1
#
# KeyboardInterrupt:

# %%
#continuation

# %%
#functions and recurssive fuctions (questions)

# %%
#sunm of list

def sum_of_list(num):
  return sum(num)
mylist = [1,2,3]
result = sum_of_list(mylist)
print(result)
# Out:
# 6

# %%
#perimeter of a rectangle

def perime(a,b):
  return 2*(a+b)
a=2
b=3
result = perime(a,b) #perime(2,3)
print(result)
# Out:
# 10

# %%
#exponenitial

def power(base,exponent):
  if exponent == 0:
    return 1
  return base * power(base, exponent-1)
print(power(2,3))
# Out:
# 8

# %%
#minimum

def findmini(num):
  return min(num)
print(findmini([4,2,1,5]))
# Out:
# 1

# %%
#maximum

def maximum(num):
  return max(num)
m=[2,5,6,20]
result=maximum(m)
print(result)
# Out:
# 20

# %%
#kilometers to meters

def km_to_m(num):
  return num * 1000
print(km_to_m(5),"m")
# Out:
# 5000 m

# %%
#fahrenheit to celsius

def fahren(f):
  c=(f-32)*5/9
  return c
print(fahren(102))
# Out:
# 38.888888888888886

# %%
#count vowels

def count_vowels(text):
  vowel="aeiouAEIOU"
  count=0
  for char in text:
    if char in vowel:
      count+=1
  return count

user_input=input("enter your name: ")
print("number of vowels")
count_vowels(user_input)
# Out:
# enter your name: aaq
# number of vowels
# 2

# %%
#lamda function

add_lambda = lambda x,y:x+y
print(add_lambda(3,5))
# Out:
# 8

# %%
#square

square = lambda x:x*x
print(square(2))
# Out:
# 4

# %%
# Map syntax

# map(fucntion, listname)

# %%
#map()

num=[1,2,3,4]
squares = list(map(lambda x:x*x, num))
print(squares)
# Out:
# [1, 4, 9, 16]

# %%
#celsius to fahrenheit using lambda fucniton

celsius = [0.0, 10.0, 20.0, 30.0]
fahren  = list( map( lambda x: (x*9/5)+32,celsius )) #map(function,list name)
print(fahren)
# Out:
# [32.0, 50.0, 68.0, 86.0]

# %%
#filter

#filter(function,list name)

# %%
#filtering even numbers from a list

num = [1,2,3,4,5,5,6,]
eve = list(filter(lambda x: x%2==0, num ))
print(eve)
# Out:
# [2, 4, 6]

# %%
#filtering marks above 60

marks = [30,20,60,59,80]
grade = list(filter(lambda x:x>=60,marks))
print(grade)
# Out:
# [60, 80]

# %%
#

num = [1,2,3,4]
c = list(map(lambda x:x*x*x,num))
print(c)
# Out:
# [1, 8, 27, 64]

# %%
#

age=[30,12,17,19,20,16]
eligible = list(filter(lambda x:x>=18,age))
print(eligible)
# Out:
# [30, 19, 20]

# %%
#sorted

#sorted(list name)

# %%
#sorted

name = ['adarsh','pranav','ithivrith','vipin']
sorte=sorted(name)
print(sorte)

#or

name = ['adarsh','pranav','ithivrith','vipin']
print(sorted(name))

#printing in reverse

name = ['adarsh','pranav','ithivrith','vipin']
sorts = sorted(name,reverse=True)
print(sorts)

#or

name = ['adarsh','pranav','ithivrith','vipin']
print(sorted(name,reverse=True))
# Out:
# ['adarsh', 'ithivrith', 'pranav', 'vipin']
# ['adarsh', 'ithivrith', 'pranav', 'vipin']
# ['vipin', 'pranav', 'ithivrith', 'adarsh']
# ['vipin', 'pranav', 'ithivrith', 'adarsh']

# %%
#sorting students according to marks

students = [('adarsh',80),('vipin',88),('pranav',92),('ithivrith',50),('yadhu',60)]
sorts = sorted(students, key = lambda x: x[1], reverse=True )
print(sorts)

#or

for i in sorts:
  print(i)

#or

students = [('adarsh',80),('vipin',88),('pranav',92),('ithivrith',50),('yadhu',60)]
sorts = sorted(students, key = lambda x: x, reverse=True )
print(sorts)
# Out:
# [('pranav', 92), ('vipin', 88), ('adarsh', 80), ('yadhu', 60), ('ithivrith', 50)]
# ('pranav', 92)
# ('vipin', 88)
# ('adarsh', 80)
# ('yadhu', 60)
# ('ithivrith', 50)
# [('yadhu', 60), ('vipin', 88), ('pranav', 92), ('ithivrith', 50), ('adarsh', 80)]

# %%
#giving parameters

def mult(n):
  return lambda a,b,c,d : n*(a+b-c+d)


mlt=mult(2)
print(mlt(1,2,3,4))

#or

print(mult(2)(1,2,3,4))
# Out:
# 8
# 8

# %%
# #map,sort,filter in single function

# result = sorted(map(lambda x: x*x,filter(lam) x%2 == 0,[3,4,1,5,2])),reverse = True)
# Out:
#   File "/tmp/ipython-input-572138594.py", line 3
#     result = sorted(map(lambda x: x*x,filter(lambda x%2 == 0,[3,4,1,5,2])),reverse = True)
#                                                      ^
# SyntaxError: invalid syntax

# %%
#object oriented programs

# %%
#CLASS
#OBJECT
#CONSTRUCTOR
#INHERITANCE
#POLYMORPHISM
#ENCAPSULATION
#ABSTRACTION

# %%
#CLASS - Blueprint
#Object - Real Instance

# %%
class Student:
  pass
s1 = Student()
print(type(s1))
# Out:
# <class '__main__.Student'>

# %%
x = 3
print(type(x))
# Out:
# <class 'int'>

# %%
class Computer:
  def config(self):
    print("ryzen 5,8GB,1TB")
com1 = Computer()
com2 = Computer()

Computer.config(com1)
com2.config()
# Out:
# ryzen 5,8GB,1TB
# ryzen 5,8GB,1TB

# %%
#constructor(__init__Method)
class Student:
  def __init__(self,name,age):
    self.name =name
    self.age = age
    print("hi")
s1 = Student("nihal",25)
s2 = Student("snishida",35)

print(s1.name)
print(s2.age)
# Out:
# hi
# hi
# nihal
# 35

# %%
class Student:
  def __init__(self):
    self.name = "sruthi"
    self.age =  25

s1 = Student()
s2 = Student()

s1.name = "abhilash"
s2.age = 27

print(s1.name)
print(s2.name)
print(s1.age)
print(s2.age)
# Out:
# abhilash
# sruthi
# 25
# 27

# %%
class Student:
  def __init__(self):
    self.name = "nihala"
    self.age =  25

  def update(self):
    self.name = "mufeeda"
    self.age = 27
s1 = Student()
s2 = Student()

s1.name="sabin"
s1.age=24

s1.update()

print(s1.name)
print(s1.age)

print(s2.name)
print(s2.age)
# Out:
# mufeeda
# 27
# nihala
# 25

# %%
#Bank account
class Bankaccount:
  def __init__(self,acc_num,balance):
    self.acc_num = acc_num
    self.balance = balance

  def deposit(self,amount):
    self.balance += amount
    print(amount,self.balance)

  def withdraw(self,amount):
    if 0< amount <self.balance:
      self.balance -= amount
      print(amount,self.balance)
    else:
      print("insufficient balance")

  def get_balance(self):
    print(self.balance)
a = Bankaccount("1234",1000)
a.get_balance()
a.deposit(500)
a.withdraw(2000)
a.get_balance()
# Out:
# 1000
# 500 1500
# insufficient balance
# 1500

# %%
#class attributes vs instance attribute

class student:
  college_name = "maharajas" #class attribute - shared by everyone.

  def __init__(self,name):
    self.name = name#instance attribute - shared only by him1

#__init__ : when init method(its a special method) is used, every object is unique,it calls automatically when the object is created.
#self : this reffers to the current object being created, it specifies it, like saying "this particular student"

s1 = student("nihal")
s2 = student("midhun")

print(s1.college_name)
print(s2.name)
# Out:
# maharajas
# midhun

# %%
#inheritance

class Animal:
  def speak(self):
    print("animal speaks")
class Dog(Animal): #inherited the things in animal class
  def bark(self):
    print("dog is barking")
d=Dog()
d.speak()
d.bark()
# Out:
# animal speaks
# dog is barking

# %%
#2.inheritance

class Animal:
  def speak(self):
    print("animal speaks")

class Cow(Animal):
  def moo(self):
    print("cow moo")

class Dog(Animal):
  def bark(self):
    print("dog barks")

#here we have to call Cow and Dog seperately(d=Dog(),a=Cow()), initialize the objects

d=Dog()
a=Cow()
d.speak()
a.moo()
d.bark()
# Out:
# animal speaks
# cow moo
# dog barks

# %%
#3.inheritance

class Grand_parents:
  def first_gen(self):
    print("1st generation-grandparent")
class parent(Grand_parents):
  def second_gen(self):
    print("2nd generation-parent")
class child(parent):
  def third_gen(self):
    print("3rd generation-child")

obj=child()
obj.first_gen()
obj.second_gen()
obj.third_gen()
# Out:
# 1st generation-grandparent
# 2nd generation-parent
# 3rd generation-child

# %%
#polymorphism (overrides)

class Animal:
  def speak(self):
    print("animal speak")
class Cat(Animal):
  def speak(self):
    print("meow")

c=Cat()
c.speak()
# Out:
# meow

# %%
class Animal:
  def __init__(self,name):
    self.name = name

  def speak(self):
    pass

class Dog(Animal):
  def speak(self):
    return f"{self.name} barks"   #f is used to fetch the names from the top (tommy)

class Cat(Animal):
  def speak(self):
    return f"{self.name} meows"

d= Dog("tommy")
c=Cat("luna")
print(d.speak())
print(c.speak())
# Out:
# tommy barks
# luna meows

# %%
class shape:
  def area(self):
    pass
class rectangle(shape):
  def __init__(self, length , width):
    self.length = length
    self.width = width

  def area (self):
    return self.length * self.width

class circle(shape):
  def __init__(self , radius):
    self.radius = radius

  def area(self):
    return 3.14 * self.radius **2

class triangle(shape):
  def __init__(self,base,height):
    self.base = base
    self.height = height

  def area(self):
    return 0.5 * self.base * self.height

shapes = [rectangle(5 , 8), circle(5), rectangle(4,8), triangle(2,3)]
for i in shapes:
  print(i.area())
# Out:
# 40
# 78.5
# 32
# 3.0

# %%
#ENCAPSULATION

#wrapping up of data, data is set private, that others cannot access to that particular data


class Bankaccount:
  def __init__(self, owner, balance):
    self.owner = owner #public variable
    self.__balance = balance #private variable

  def deposit(self, amount):
    if amount>0:
      self.__balance += amount

  def withdraw(self,amount):
    if amount <= self.__balance:
      self.__balance -= amount
      return True
    else:
      return False

  def get_balance(self):
    return self.__balance

#create an account with Rs1000
account = Bankaccount("Alice",1000)

#try to set balance directly  ( wont affect real balance)
account.__balance = -1000

#show balance ( should still be Rs1000)
print("balance after invalid direct change",account.get_balance())

#deposit Rs 500
account.deposit(500)

#withdraw Rs 300
account.withdraw(300)

#show final balance
print("final balance after deposit and withdrawal: ",account.get_balance())
# Out:
# balance after invalid direct change 1000
# final balance after deposit and withdrawal:  1200

# %%
class Bankaccount:
  def __init__(self, owner, balance):
    self.owner = owner
    self.balance = balance #public variable
  def deposit(self,amount):
    if amount>0:
      self.balance += amount

  def withdraw(self, amount):
    if amount <=self.balance:
      self.balance -= amount
      return True
    else:
      return False

  def get_balance(self):
    return self.balance

#create account
account = Bankaccount("alice",1000)

#directly modify  balance( no protection)
account.balance = -1000

#check balance
print("balance after direct change", account.get_balance())
# Out:
# balance after direct change -1000

# %%
# ABSTRACTION

#  abstraction is the process of hiding implementation details, shows only the essential details

# we cannot create objects of an abbstraction class

# we cannot use directly ( python doesnt support this ), we should import it. (from abc import ABC, abstractionmethod)

# all methods which we called in first class should be called in each class.

# %%
from abc import ABC, abstractmethod

class Vehicle(ABC):
  @abstractmethod
  def start(self):
    pass

  @abstractmethod
  def stop(self):
    pass

class Car(Vehicle):
  def start(self):
    return "car started"

  def stop(self):
    return "car stopped"

class Bike(Vehicle):
  def start(self):
    return "bike started"

  def stop(self):
    return "bike stopped"

#create objects
car_obj = Car()
bike_obj = Bike()

print(car_obj.start())
print(car_obj.stop())

print(bike_obj.start())
print(bike_obj.stop())

# %%
from abc import ABC, abstractmethod

class Vehicle(ABC):
  @abstractmethod
  def start(self):
    pass
  @abstractmethod
  def stop(self):
    pass

class Car(Vehicle):
  def start(self):
    return "push start"

  def stop(self):
    return "push stop"

class Bike(Vehicle):
  def start(self):
    return "kick start"

  def stop(self):
    return "key stop"

class Scooter(Vehicle):
  def start(self):
    return "self start"

  def stop(self):
    return "key  stop"

#object creation
c = Car()
b = Bike()
s = Scooter()

print(c.start())
print(c.stop())
print(b.start())
print(b.stop())
print(s.start())
print(s.stop())
# Out:
# push start
# push stop
# kick start
# key stop
# self start
# key  stop
